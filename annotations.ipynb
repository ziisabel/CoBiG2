# %%
import sys
import json
import requests
from urllib.request import urlopen
import csv
import os
import os.path

# %%
def get_prot_name(filename):
    
    # Print the description lines of a BLASTX file
    blast_file = open(filename, 'r')
    line = blast_file.readline()

    # Sanity check that this is a BLASTX output text file
    if not line.startswith("BLASTX"):
        #raise TypeError("Not a BLASTX file: %r" % version)
        print("Not a BLASTX file: %r" % version)
        print(None)

    content = blast_file.readlines()
    lines = []

    for line in content:

        if line.startswith(">"):
            prot_name = line[1:].strip('\n ')
            prot_name = prot_name[:prot_name.find(' [')]
            prot_name = prot_name[prot_name.find(' '):][1:]
            lines.append(prot_name)

        if not line:
            # End of file - this should not happen
            print("Could not find the description section")
            print(None)

    prot_names = []

    # Return proteins
    for line in lines:
            prot_names.append(line)
            
    prot_names = list(dict.fromkeys(prot_names))
    return prot_names


def get_full_annotation(trinityId, protName, degGenes):
    
    #print(protName)
    protUni = str(protName.replace(' ', '+'))
    
    unknowList = ['hypothetical', 'uncharacterized', 'unknown', 'unnamed']
    if not any(term in protName.lower() for term in unknowList):

        # First get the Uniprot data
        link = 'https://www.uniprot.org/uniprot/?query=%22' + protUni + '%22,&columns=id,entry%20name&format=tab&sort=score'
        #print(link)
        html = urlopen(link).readlines()

        protId = ''
        geneId = ''

        if html != []:

            for entry in html:
                decodedHtml = entry.decode("utf-8")
                #print(decodedHtml)
                if '_ARATH' in decodedHtml:
                    protId = decodedHtml.split()[1]
                    break

            if protId == '':
                decodedHtml = html[1].decode("utf-8")
                protId = decodedHtml.split()[1]

            urllink = 'https://www.uniprot.org/uniprot/' + protId + '.txt'
            #print(urllink)
            url = urlopen(urllink)

            urlheader = url.readline().decode("utf-8").strip('\n').split()
            urltxt = url.readlines()

            goCC = []
            goMF = []
            goBP = []

            for entry in urltxt:
                line = str(entry.decode("utf-8")).strip('\n')[:-1]

                if line.startswith('GN   Name='):
                    geneId = line[10:].split(';')[0].strip()
                elif line.startswith('GN   ORFNames='):
                    geneId = line[14:].split(';')[0].strip()
                elif line.startswith('GN   OrderedLocusNames='):
                    geneId = line[23:].split(';')[0].strip()
                
                if geneId.find('{') != -1:
                    geneId = geneId[:geneId.find('{')].strip()

                if line.startswith('DR   GO'):

                    goName = ((line[9:].split('; ')[1:-1]))

                    if goName[0].startswith('C:'):
                        goCC.append(goName[0].replace('C:', ''))

                    elif goName[0].startswith('F:'):
                        goMF.append(goName[0].replace('F:', ''))

                    elif goName[0].startswith('P:'):
                        goBP.append(goName[0].replace('P:', ''))

            strGoCC = ', '.join(goCC)
            strGoMF = ', '.join(goMF)
            strGoBP = ', '.join(goBP)
            
            if geneId == '':
                geneId = 'N/A'

            tabRow = {trinityId: [geneId, protName, protId, strGoCC, strGoMF, strGoBP]} # degFC
            print(tabRow)

            return tabRow
        
        else:
            return None

    
    else:
        tabRow = {trinityId: ['Unknown', protName]} # degFC
        print(tabRow)
        degGenes.update(tabRow)

        return degGenes


def get_ancestors(go_ids):
    
    ancestors = {}
    
    for go_id in go_ids:
    
        the_url = 'https://www.ebi.ac.uk/QuickGO/services/ontology/go/terms/' + go_id
        response = requests.get(the_url)
        data = json.loads(response.text)

        record = data['results'][0] # Get the first result, because we are only requesting one!

        # Return a dictionary that contains the information of this GO term
        go_info = {
            'go_id': record['id'],
            'aspect': record['aspect'],
            'name': record['name'],
            'definition': record['definition']['text'],
            'obsolete': record['isObsolete'],
        }
        
        go_infos.update({go_id: [go_info[aspect], go_info[name]]})

    return go_infos

# %%
trinity = 'TRINITY_DN349_c1_g1'
prot = 'glutathione S-transferase'

protUni = str(prot.replace(' ', '+'))
print(protUni)

# First get the Uniprot data
link = 'https://www.uniprot.org/uniprot/?query=%22' + protUni + '%22,&columns=id,entry%20name&format=tab&sort=score'
print(link)
html = urlopen(link).readlines()

protId = ''
geneId = ''

if html != []:
    print(html)

    for entry in html:
        decodedHtml = entry.decode("utf-8")
        print(decodedHtml)
        if '_ARATH' in decodedHtml:
            protId = decodedHtml.split()[1]
            break

    if protId == '':
        decodedHtml = html[1].decode("utf-8")
        protId = decodedHtml.split()[1]

    urllink = 'https://www.uniprot.org/uniprot/' + protId + '.txt'
    #print(urllink)
    url = urlopen(urllink)

    urlheader = url.readline().decode("utf-8").strip('\n').split()
    urltxt = url.readlines()

    goCC = []
    goMF = []
    goBP = []

    for entry in urltxt:
        line = str(entry.decode("utf-8")).strip('\n')[:-1]

        if line.startswith('GN   Name='):
            geneId = line[10:].split(';')[0].strip()
        elif line.startswith('GN   ORFNames='):
            geneId = line[14:].split(';')[0].strip()
        elif line.startswith('GN   OrderedLocusNames='):
            geneId = line[23:].split(';')[0].strip()

        if geneId.find('{') != -1:
            geneId = geneId[:geneId.find('{')].strip()

        if line.startswith('DR   GO'):

            goName = ((line[9:].split('; ')[1:-1]))

            if goName[0].startswith('C:'):
                goCC.append(goName[0].replace('C:', ''))

            elif goName[0].startswith('F:'):
                goMF.append(goName[0].replace('F:', ''))

            elif goName[0].startswith('P:'):
                goBP.append(goName[0].replace('P:', ''))

    strGoCC = ', '.join(goCC)
    strGoMF = ', '.join(goMF)
    strGoBP = ', '.join(goBP)

    if geneId == '':
        geneId = 'N/A'

    tabRow = {trinityId: [geneId, protName, protId, strGoCC, strGoMF, strGoBP]} # degFC
    print(tabRow)

    return tabRow

else:
    return None

print(degGenes)
# Out:
# glutathione+S-transferase
# https://www.uniprot.org/uniprot/?query=%22glutathione+S-transferase%22,&columns=id,entry%20name&format=tab&sort=score
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-195d595a6f43> in <module>
#       8 link = 'https://www.uniprot.org/uniprot/?query=%22' + protUni + '%22,&columns=id,entry%20name&format=tab&sort=score'
#       9 print(link)
# ---> 10 html = urlopen(link).readlines()
#      11
#      12 protId = ''
#
# /opt/anaconda3/lib/python3.7/http/client.py in readline(self, limit)
#     672         if self.chunked:
#     673             # Fallback to IOBase readline which uses peek() and read()
# --> 674             return super().readline(limit)
#     675         if self.length is not None and (limit < 0 or limit > self.length):
#     676             limit = self.length
#
# /opt/anaconda3/lib/python3.7/http/client.py in peek(self, n)
#     664             return b""
#     665         if self.chunked:
# --> 666             return self._peek_chunked(n)
#     667         return self.fp.peek(n)
#     668
#
# /opt/anaconda3/lib/python3.7/http/client.py in _peek_chunked(self, n)
#     707         # peek is allowed to return more than requested.  Just request the
#     708         # entire chunk, and truncate what we get.
# --> 709         return self.fp.peek(chunk_left)[:chunk_left]
#     710
#     711     def fileno(self):
#
# /opt/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /opt/anaconda3/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /opt/anaconda3/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
path = 'Blast/blastx_out/'
files = os.listdir(path)
#print(files)

unknowList = ['hypothetical', 'uncharacterized', 'unknown', 'unnamed']

for file in files:
    filename = ''.join(path + file)
    trinity = file.replace('_blastx', '')

    if trinity not in degGenes:
        print(trinity)
        
        annotation = None
        protList = get_prot_name(filename)

        if protList != []:

            protKnownList = []

            for prot in protList:
                if not any(term in prot.lower() for term in unknowList):
                    protKnownList.append(prot)

            if protKnownList != []:
                for prot in protKnownList:
                    print(prot)
                    annotation = get_full_annotation(trinity, prot, degGenes)
                    print(annotation)
                    if annotation != None:
                        break

            else:
                for prot in protList:
                    annotation = get_full_annotation(trinity, prot, degGenes)
                    if annotation != None:
                        break

            if annotation != None:
                degGenes.update(annotation)

        else:
            annotation = {trinity: ['Unkown', 'Unkown protein']}
            degGenes.update(annotation)
# Out:
# TRINITY_DN349_c1_g1
# glutathione S-transferase
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-279dd2cf1dc5> in <module>
#      26                 for prot in protKnownList:
#      27                     print(prot)
# ---> 28                     annotation = get_full_annotation(trinity, prot, degGenes)
#      29                     print(annotation)
#      30                     if annotation != None:
#
# <ipython-input-2-5b5caa9a6a9d> in get_full_annotation(trinityId, protName, degGenes)
#      48         link = 'https://www.uniprot.org/uniprot/?query=%22' + protUni + '%22,&columns=id,entry%20name&format=tab&sort=score'
#      49         #print(link)
# ---> 50         html = urlopen(link).readlines()
#      51
#      52         protId = ''
#
# /opt/anaconda3/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /opt/anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# /opt/anaconda3/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# /opt/anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# /opt/anaconda3/lib/python3.7/urllib/request.py in https_open(self, req)
#    1358         def https_open(self, req):
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#    1362         https_request = AbstractHTTPHandler.do_request_
#
# /opt/anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318             except OSError as err: # timeout error
#    1319                 raise URLError(err)
# -> 1320             r = h.getresponse()
#    1321         except:
#    1322             h.close()
#
# /opt/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1334         try:
#    1335             try:
# -> 1336                 response.begin()
#    1337             except ConnectionError:
#    1338                 self.close()
#
# /opt/anaconda3/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# /opt/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# /opt/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /opt/anaconda3/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /opt/anaconda3/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
degGenes
# Out:
# {'TRINITY_DN12535_c0_g2': ['At2g25060',
#   'early nodulin-like protein 1',
#   'ENL1_ARATH',
#   'anchored component of membrane, anchored component of plasma membrane, plasma membrane, plasmodesma, secretory vesicle, vacuole',
#   'electron transfer activity',
#   ''],
#  'TRINITY_DN11878_c0_g1': ['CKAN_01401800',
#   'UDP-glycosyltransferase 90A1-like',
#   'A0A443P332_9MAGN',
#   '',
#   'transferase activity, transferring hexosyl groups',
#   ''],
#  'TRINITY_DN68706_c0_g1': ['STAS_14199',
#   'acyl-CoA N-acyltransferases super family protein',
#   'A0A5A7PYZ1_STRAF',
#   '',
#   'transferase activity, transferring acyl groups',
#   ''],
#  'TRINITY_DN13077_c0_g5': ['COBL4',
#   'COBRA-like protein 4',
#   'COBL4_ARATH',
#   'anchored component of membrane, anchored component of plasma membrane, plasma membrane, vacuolar membrane',
#   '',
#   'cellulose microfibril organization, plant-type cell wall biogenesis, plant-type cell wall cellulose biosynthetic process, plant-type cell wall organization, plant-type secondary cell wall biogenesis'],
#  'TRINITY_DN3291_c0_g1': ['LOC103697761',
#   'ras GTPase-activating protein-binding protein 1-like',
#   'A0A2H3X3V9_PHODC',
#   'cytosol, ribonucleoprotein complex',
#   'mRNA binding',
#   '']}

# %%
fileannot = 'DEGannotations_0702.tab'

with open(fileannot, 'w') as annotFile:
    writer = csv.writer(annotFile, dialect="excel-tab")
    writer.writerow(['Trinity Id', 'Gene Id', 'Protein Name', 'Prot Id', 'Cellular Component', 'Molecular Function', 'Biological Process'])
    
    for gene in degGenes:
        writer.writerow([gene, degGenes[gene]])
        
annotFile.close()

# %%
for file in files:
    if file.replace('_blastx','') not in degGenes:

# %%
uniprotIdList = []

for gene in degGenes:
    if len(degGenes[gene]) > 2:
        uniprotIdList.append(degGenes[gene][2])
", ".join(uniprotIdList).strip()

# %%
mol_function = {}

for gene in degGenes:
    if len(degGenes[gene]) > 2:
        mf_list = degGenes[gene][4].split(',')
        
        for function in mf_list:
            if function != '':
                if function not in mol_function:
                    mol_function[function.strip()] = 1
                else:
                    mol_function[function.strip()] += 1

mol_function
{k: v for k, v in sorted(mol_function.items(), key=lambda item: item[1], reverse=True)}

#sorted_x.reverse()
# Out:
# {'transferase activity': 2,
#  'electron transfer activity': 1,
#  'transferring hexosyl groups': 1,
#  'transferring acyl groups': 1,
#  'mRNA binding': 1}

# %%
for gene in degGenes:
    if len(degGenes[gene]) > 2:
        print(degGenes[gene][0])
    else:
        continue

# %%
fileannot = 'DEGannotations_0502.tab'

d = {}
with open(fileannot, 'r') as annotFile:
    header = annotFile.readline()
    for row in csv.reader(annotFile, delimiter='\t'):
        d[row[0]] = row[1:]
        
annotFile.close()

d
# Out:
# {'At2g25060': ['early nodulin-like protein 1',
#   'ENL1_ARATH',
#   'anchored component of membrane, anchored component of plasma membrane, plasma membrane, plasmodesma, secretory vesicle, vacuole',
#   'electron transfer activity',
#   ''],
#  'CKAN_01401800': ['UDP-glycosyltransferase 90A1-like',
#   'A0A443P332_9MAGN',
#   '',
#   'transferase activity, transferring hexosyl groups',
#   ''],
#  'STAS_14199': ['acyl-CoA N-acyltransferases super family protein',
#   'A0A5A7PYZ1_STRAF',
#   '',
#   'transferase activity, transferring acyl groups',
#   ''],
#  'COBL4': ['COBRA-like protein 4',
#   'COBL4_ARATH',
#   'anchored component of membrane, anchored component of plasma membrane, plasma membrane, vacuolar membrane',
#   '',
#   'cellulose microfibril organization, plant-type cell wall biogenesis, plant-type cell wall cellulose biosynthetic process, plant-type cell wall organization, plant-type secondary cell wall biogenesis'],
#  'LOC103697761': ['ras GTPase-activating protein-binding protein 1-like',
#   'A0A2H3X3V9_PHODC',
#   'cytosol, ribonucleoprotein complex',
#   'mRNA binding',
#   ''],
#  'F17A22.12': ['glutathione S-transferase',
#   'GSTF8_ARATH',
#   'chloroplast, chloroplast envelope, chloroplast stroma, cytoplasm, cytosol, nucleus, stromule, thylakoid, vacuolar membrane',
#   'glutathione binding, glutathione transferase activity, peroxidase activity',
#   'cellular response to hypoxia, defense response, defense response to bacterium, glutathione metabolic process, response to cold, response to karrikin, toxin catabolic process'],
#  'VITISV_036418': ['DUF588 domain-containing protein',
#   'A5AM50_VITVI',
#   'integral component of membrane, plasma membrane, protein farnesyltransferase complex',
#   'catalytic activity',
#   'protein farnesylation'],
#  'WAKL16': ['putative wall-associated receptor kinase-like 16',
#   'WAKLS_ARATH',
#   'integral component of membrane, plasma membrane',
#   'ATP binding, protein serine/threonine kinase activity',
#   ''],
#  'MtrunA17_Chr4g0036961': ['3-oxo-Delta(4,5)-steroid 5-beta-reductase-like',
#   'G7JMD3_MEDTR',
#   '',
#   'oxidoreductase activity',
#   ''],
#  'At5g66900': ['probable disease resistance protein At5g66900',
#   'DRL42_ARATH',
#   'cytosol, endomembrane system',
#   'ADP binding, ATP binding, ubiquitin binding',
#   'defense response'],
#  'LOC107922654': ['protein NIM1-INTERACTING 1-like',
#   'A0A1U8L4H7_GOSHI',
#   '',
#   '',
#   'regulation of systemic acquired resistance'],
#  'Unknown': ['unnamed protein product'],
#  'K14B20.10': ['kinesin heavy chain',
#   'KN14E_ARATH',
#   'cortical microtubule, cytoskeleton, kinesin complex, microtubule, mitotic spindle, phragmoplast',
#   'actin filament binding, ADP binding, ATP binding, ATP-dependent microtubule motor activity, minus-end-directed, ATPase activity, calcium ion binding, calmodulin binding, microtubule binding, microtubule motor activity, oxidoreductase activity, protein homodimerization activity, protein kinase binding',
#   'cortical microtubule organization, microtubule bundle formation, microtubule-based movement, trichome branching, trichome patterning'],
#  'rpl16': ['50S ribosomal protein L16, chloroplastic',
#   'RK16_ARATH',
#   'chloroplast, chloroplast envelope, chloroplast stroma, mitochondrial large ribosomal subunit, plastid',
#   'rRNA binding, structural constituent of ribosome',
#   'mitochondrial translation'],
#  'LOC107954095': ["abscisic acid 8'-hydroxylase 2-like",
#   'A0A1U8P1H0_GOSHI',
#   'integral component of membrane',
#   'heme binding, iron ion binding, monooxygenase activity, oxidoreductase activity, acting on paired donors, with incorporation or reduction of molecular oxygen',
#   'oxidation-reduction process, sterol metabolic process'],
#  'FLS2': ['LRR receptor-like serine/threonine-protein kinase FLS2',
#   'FLS2_ARATH',
#   'endosome, endosome membrane, integral component of membrane, membrane, plasma membrane',
#   'ATP binding, identical protein binding, transmembrane receptor protein serine/threonine kinase activity',
#   'defense response by callose deposition in cell wall, defense response to bacterium, detection of bacterium, receptor-mediated endocytosis, regulation of anion channel activity'],
#  'LNG1': ['protein LONGIFOLIA 1',
#   'LNG1_ARATH',
#   'cytosol, nucleus',
#   '',
#   'regulation of monopolar cell growth, unidimensional cell growth'],
#  'Unkown': ['Unkown protein'],
#  'LIP2': ['Triacylglycerol lipase 2',
#   'LIP2_ARATH',
#   'extracellular region',
#   'lipase activity, triglyceride lipase activity',
#   'defense response to insect, lipid catabolic process'],
#  'F25A4.30': ['transmembrane protein, putative',
#   'Q94F10_ARATH',
#   'chloroplast, chloroplast thylakoid, chloroplast thylakoid membrane, granal stacked thylakoid, integral component of membrane, mitochondrion',
#   '',
#   'granum assembly, nonphotochemical quenching, thylakoid membrane organization'],
#  'F22D1.60': ['T-complex protein 1 subunit beta',
#   'TCPB_ARATH',
#   'anchored component of plasma membrane, cell wall, chaperonin-containing T-complex, cytosol, plastid',
#   'ATP binding, unfolded protein binding',
#   'protein folding'],
#  'LOC107889647': ['L-type lectin-domain containing receptor kinase IV.1-like',
#   'A0A1U8HUF7_GOSHI',
#   'integral component of membrane, plasma membrane',
#   'ATP binding, carbohydrate binding, transmembrane receptor protein serine/threonine kinase activity',
#   'defense response, defense response to bacterium, defense response to oomycetes'],
#  'CYP71A1': ['Cytochrome P450 71A1',
#   'C71A1_PERAE',
#   'endoplasmic reticulum membrane, integral component of membrane',
#   'heme binding, iron ion binding, monooxygenase activity, oxidoreductase activity, acting on paired donors, with incorporation or reduction of molecular oxygen',
#   'fruit ripening'],
#  'LRX2': ['Leucine-rich repeat extensin-like protein 2',
#   'LRX2_ARATH',
#   'cell wall, extracellular region',
#   '',
#   'cell wall organization, multicellular organism development'],
#  'LOC108985525': ['protein SIEVE ELEMENT OCCLUSION B-like isoform X1',
#   'A0A2I4E1Y7_JUGRE',
#   '',
#   '',
#   'phloem development'],
#  'LOC107953382': ['scopoletin glucosyltransferase-like',
#   'A0A1U8P1E7_GOSHI',
#   'intracellular membrane-bounded organelle',
#   'transferase activity, transferring hexosyl groups, UDP-glycosyltransferase activity',
#   ''],
#  'VTA1': ['vacuolar protein sorting-associated protein VTA1 homolog',
#   'VTA1_HUMAN',
#   'cytosol, endosome membrane, extracellular exosome, intracellular membrane-bounded organelle, nucleoplasm',
#   'protein C-terminus binding',
#   'endosomal transport, ESCRT III complex disassembly, macroautophagy, multivesicular body assembly, multivesicular body sorting pathway, protein transport, viral budding, viral life cycle'],
#  'MYB5': ['Transcription repressor MYB5',
#   'MYB5_ARATH',
#   'nucleus',
#   'DNA-binding transcription factor activity, sequence-specific DNA binding, transcription regulatory region DNA binding',
#   'cell differentiation, mucilage biosynthetic process involved in seed coat development, regulation of gene expression, seed coat development, trichome morphogenesis'],
#  'LOC107781838': ['rust resistance kinase Lr10-like',
#   'A0A1S3Z0W0_TOBAC',
#   'integral component of membrane',
#   'ATP binding, polysaccharide binding, protein kinase activity',
#   ''],
#  'ZICARI_052': ['putative DNA-directed RNA polymerase, subunit beta-prime',
#   'E0TIP8_ZINIC',
#   '',
#   "DNA binding, DNA-directed 5'-3' RNA polymerase activity",
#   'transcription, DNA-templated'],
#  'LOC106772860': ['BTB/POZ domain-containing protein At1g03010 isoform X2',
#   'A0A1S3V9E2_VIGRR',
#   '',
#   '',
#   ''],
#  'N/A': ['non-LTR retroelement reverse transcriptase-like protein',
#   'Q9LRU8_ARATH',
#   'integral component of membrane',
#   'RNA-directed DNA polymerase activity',
#   '']}
